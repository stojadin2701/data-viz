# %%
import pandas as pd
from sys import getsizeof

# %%
PATH_FILES = list(map(
    lambda x: '../data/data_2017-11-' + str(x) + '_2017-11-' + str(x) + '.csv',
    range(1, 16))) + ['/Users/lia/work/study/epfl/COM480-DataVisualization/data-viz/data/data_2017-10-2_2017-10-2.csv']

# %%
df = pd.DataFrame()
for p in PATH_FILES:
    df = pd.concat([df, pd.read_csv(p)])

# %%
df.shape
# Out:
# (510118, 40)

# %%
df.columns
# Out:
# Index(['id', 'created_at', 'type', 'public', 'actor.id', 'actor.url',
#        'actor.display_login', 'org.id', 'payload.action', 'payload.number',
#        'payload.pull_request.number', 'payload.pull_request.title',
#        'payload.pull_request.comments', 'payload.pull_request.commits',
#        'payload.pull_request.author_association',
#        'payload.pull_request.additions', 'payload.pull_request.created_at',
#        'payload.pull_request.closed_at', 'payload.pull_request.merged',
#        'payload.pull_request.merged_at', 'payload.pull_request.merged_by.id',
#        'payload.pull_request.merged_by.login',
#        'payload.pull_request.merged_by.type', 'repo.id', 'repo.name',
#        'repo.url', 'payload.pull_request.head.repo.pushed_at',
#        'payload.pull_request.author_association.1',
#        'payload.pull_request.base.repo.created_at',
#        'payload.pull_request.base.repo.language',
#        'payload.pull_request.base.repo.watchers_count',
#        'payload.pull_request.base.repo.open_issues_count',
#        'payload.pull_request.head.repo.size',
#        'payload.pull_request.changed_files',
#        'payload.pull_request.head.repo.description',
#        'payload.pull_request.head.repo.has_downloads',
#        'payload.pull_request.head.repo.has_issues',
#        'payload.pull_request.head.repo.has_pages',
#        'payload.pull_request.head.repo.has_projects',
#        'payload.pull_request.head.repo.has_wiki'],
#       dtype='object')

# %%
def create_new_cols(df):
    df['days_open_merged'] = ((pd.to_datetime(df['payload.pull_request.merged_at'])
                               - pd.to_datetime(df['payload.pull_request.created_at']))
                              .apply(lambda x: x.days))
    df['creator_merge'] = df['payload.pull_request.merged_by.login'] == df['actor.display_login']
    df['cohort'] = pd.to_datetime(df['created_at']).apply(lambda x: x.strftime('%Y-%m'))

    return df

# %%
df = create_new_cols(df)

# %%
LANGUAGES = ['JavaScript', 'Java', 'Python', 'HTML', 'PHP', 'C++', 'C#', 'CSS', 'Go',
             'C', 'Shell', 'Swift', 'PowerShell', 'Scala', 'Jupyter Notebook']

# %%
df_filtered = df[df['payload.pull_request.base.repo.language'].apply(lambda x: x in LANGUAGES)]

# %%
df.groupby(['payload.pull_request.base.repo.language']).size().sort_values(ascending=False).iloc[0:20]
# Out:
# payload.pull_request.base.repo.language
# JavaScript          107792
# Java                 55026
# Python               54308
# HTML                 36098
# Ruby                 30888
# PHP                  26576
# C++                  21332
# TypeScript           16991
# C#                   16944
# CSS                  16748
# Go                   16033
# C                    11587
# Shell                10432
# Swift                 4967
# PowerShell            4730
# Scala                 4625
# Jupyter Notebook      3165
# Rust                  2771
# Objective-C           2645
# Kotlin                1964
# dtype: int64

# %%
(df_filtered.groupby(['repo.name', 'payload.pull_request.base.repo.language'])
 .size().sort_values(ascending=False).iloc[0:10])
# Out:
# repo.name                                 payload.pull_request.base.repo.language
# datasciencecampus/sdg-indicators          CSS                                        1049
# OPS-E2E-Prod/E2E_DocsBranch_Prod_Dynamic  PowerShell                                  865
# OPS-E2E-PPE/E2E_DocsBranch_Dynamic        PowerShell                                  850
# freeCodeCamp/guides                       JavaScript                                  766
# brianchandotcom/liferay-portal            Java                                        620
# kubernetes/kubernetes                     Go                                          612
# LanguageResources/Homework                Jupyter Notebook                            489
# voidlinux/void-packages                   Shell                                       456
# Automattic/wp-calypso                     JavaScript                                  425
# code-dot-org/code-dot-org                 JavaScript                                  380
# dtype: int64

# %%
(df_filtered.groupby(['payload.pull_request.base.repo.language'])
 .mean()['payload.pull_request.changed_files']
 .sort_values(ascending=False).iloc[0:10]
 .apply(lambda x: round(x,2)))
# Out:
# payload.pull_request.base.repo.language
# C             53.22
# C#            49.66
# Go            44.37
# PHP           42.16
# C++           40.23
# CSS           39.49
# Java          38.07
# PowerShell    36.93
# JavaScript    35.83
# HTML          30.23
# Name: payload.pull_request.changed_files, dtype: float64

# %%
(df_filtered.groupby(['payload.pull_request.base.repo.language'])
 .mean()['payload.pull_request.merged']
 .sort_values(ascending=False).iloc[0:10]
 .apply(lambda x: round(x,2)))
# Out:
# payload.pull_request.base.repo.language
# Swift               0.90
# HTML                0.89
# CSS                 0.89
# Jupyter Notebook    0.89
# C#                  0.87
# JavaScript          0.86
# PHP                 0.86
# Go                  0.85
# C++                 0.84
# Java                0.83
# Name: payload.pull_request.merged, dtype: float64

# %%
(df_filtered.groupby(['payload.pull_request.base.repo.language'])
 .mean()['payload.pull_request.number']
 .sort_values(ascending=False).iloc[0:10]
 .apply(lambda x: round(x,2)))
# Out:
# payload.pull_request.base.repo.language
# PowerShell    3774.01
# Go            3535.24
# C++           2053.16
# Scala         1477.23
# Python        1420.07
# C#            1212.23
# Java          1187.96
# PHP           1167.65
# C             1075.37
# Shell         1003.20
# Name: payload.pull_request.number, dtype: float64

# %%
(df_filtered.groupby(['payload.pull_request.base.repo.language'])
 .mean()['days_open_merged']
 .sort_values(ascending=False).iloc[0:10]
 .apply(lambda x: round(x,2)))
# Out:
# payload.pull_request.base.repo.language
# C             6.76
# C++           5.94
# PHP           5.67
# Shell         5.41
# Python        5.31
# Go            4.13
# Scala         3.78
# PowerShell    3.40
# JavaScript    3.37
# Java          3.11
# Name: days_open_merged, dtype: float64

# %%
(df_filtered.groupby(['payload.pull_request.base.repo.language'])
 .mean()['payload.pull_request.commits']
 .sort_values(ascending=False).iloc[0:10]
 .apply(lambda x: round(x,2)))
# Out:
# payload.pull_request.base.repo.language
# C                   31.03
# C++                 18.10
# Java                14.31
# Go                  11.16
# PowerShell           9.14
# Python               8.61
# C#                   8.10
# Jupyter Notebook     7.96
# PHP                  7.64
# JavaScript           6.96
# Name: payload.pull_request.commits, dtype: float64

# %%
(df_filtered.groupby(['payload.pull_request.base.repo.language'])
 .mean()['payload.pull_request.comments']
 .sort_values(ascending=False).iloc[0:10]
 .apply(lambda x: round(x,2)))
# Out:
# payload.pull_request.base.repo.language
# Go            1.99
# PowerShell    1.71
# Scala         1.65
# C             1.64
# C++           1.60
# Python        1.00
# Shell         0.87
# Java          0.81
# C#            0.68
# JavaScript    0.66
# Name: payload.pull_request.comments, dtype: float64

# %%
(df_filtered.groupby(['payload.pull_request.base.repo.language'])
 .mean()['payload.pull_request.base.repo.open_issues_count']
 .sort_values(ascending=False).iloc[0:10]
 .apply(lambda x: round(x,2)))
# Out:
# payload.pull_request.base.repo.language
# Go            343.00
# C++           152.34
# Python        131.33
# C#            121.54
# C             113.58
# JavaScript     81.03
# Scala          72.54
# Shell          66.77
# PHP            65.79
# Java           40.93
# Name: payload.pull_request.base.repo.open_issues_count, dtype: float64

# %%
agg = df.groupby(['payload.pull_request.base.repo.language']).describe()

# %%
pd.DataFrame(agg.unstack()).reset_index()
# Out:
#         level_0 level_1 payload.pull_request.base.repo.language            0
# 0      actor.id   count                           1C Enterprise         46.0
# 1      actor.id   count                                    ABAP         16.0
# 2      actor.id   count                                    AMPL          6.0
# 3      actor.id   count                                   ANTLR         20.0
# 4      actor.id   count                           API Blueprint         63.0
# 5      actor.id   count                                     APL          4.0
# 6      actor.id   count                                     ASP        140.0
# 7      actor.id   count                            ActionScript         66.0
# 8      actor.id   count                                     Ada         14.0
# 9      actor.id   count                                    Agda          4.0
# 10     actor.id   count                                   Alloy          5.0
# 11     actor.id   count                             AngelScript         12.0
# 12     actor.id   count                              ApacheConf         15.0
# 13     actor.id   count                                    Apex        169.0
# 14     actor.id   count                             AppleScript          5.0
# 15     actor.id   count                                     Arc          1.0
# 16     actor.id   count                                 Arduino        423.0
# 17     actor.id   count                                 AspectJ          2.0
# 18     actor.id   count                                Assembly        285.0
# 19     actor.id   count                                  Augeas          4.0
# 20     actor.id   count                              AutoHotkey         26.0
# 21     actor.id   count                                  AutoIt          7.0
# 22     actor.id   count                                     Awk          4.0
# 23     actor.id   count                               Ballerina         11.0
# 24     actor.id   count                               Batchfile        336.0
# 25     actor.id   count                                 BitBake        136.0
# 26     actor.id   count                              BlitzBasic          1.0
# 27     actor.id   count                                Bluespec          1.0
# 28     actor.id   count                               Brainfuck          8.0
# 29     actor.id   count                            Brightscript          5.0
# ...         ...     ...                                     ...          ...
# 28650   repo.id     max                                     TLA   68731208.0
# 28651   repo.id     max                                     TXL  108964876.0
# 28652   repo.id     max                                     Tcl  109869912.0
# 28653   repo.id     max                                     TeX  110743954.0
# 28654   repo.id     max                                   Terra   50964104.0
# 28655   repo.id     max                                  Thrift   79456579.0
# 28656   repo.id     max                              TypeScript  110898549.0
# 28657   repo.id     max                            UnrealScript  110606649.0
# 28658   repo.id     max                                     VCL  110655667.0
# 28659   repo.id     max                                    VHDL  110353453.0
# 28660   repo.id     max                                    Vala  110861222.0
# 28661   repo.id     max                                 Verilog  110889654.0
# 28662   repo.id     max                              Vim script  110680864.0
# 28663   repo.id     max                                    VimL   77254394.0
# 28664   repo.id     max                            Visual Basic  110856502.0
# 28665   repo.id     max                                    Volt   48581027.0
# 28666   repo.id     max                                     Vue  110806067.0
# 28667   repo.id     max                   Web Ontology Language   74678981.0
# 28668   repo.id     max                             WebAssembly  110373312.0
# 28669   repo.id     max                                      XC   47563994.0
# 28670   repo.id     max                                     XML   30999438.0
# 28671   repo.id     max                                   XProc   23045033.0
# 28672   repo.id     max                                  XQuery  110499501.0
# 28673   repo.id     max                                      XS  108800285.0
# 28674   repo.id     max                                    XSLT  110730797.0
# 28675   repo.id     max                                   Xtend  110669641.0
# 28676   repo.id     max                                    Yacc  110439706.0
# 28677   repo.id     max                                    nesC  104364498.0
# 28678   repo.id     max                                     wdl  105283002.0
# 28679   repo.id     max                                   xBase  109899055.0
#
# [28680 rows x 4 columns]

# %%
LANGUE_COL = ['payload.pull_request.base.repo.language', 'cohort']

# %%
agg = df.groupby(LANGUE_COL).describe()

# %%
pd.DataFrame(agg.unstack(1).unstack(1)).reset_index()
# Out:
#         level_0 level_1   cohort payload.pull_request.base.repo.language  \
# 0      actor.id   count  2017-10                           1C Enterprise
# 1      actor.id   count  2017-10                                    ABAP
# 2      actor.id   count  2017-10                              AGS Script
# 3      actor.id   count  2017-10                                    AMPL
# 4      actor.id   count  2017-10                                   ANTLR
# 5      actor.id   count  2017-10                           API Blueprint
# 6      actor.id   count  2017-10                                     APL
# 7      actor.id   count  2017-10                                     ASP
# 8      actor.id   count  2017-10                            ActionScript
# 9      actor.id   count  2017-10                                     Ada
# 10     actor.id   count  2017-10                                    Agda
# 11     actor.id   count  2017-10                                   Alloy
# 12     actor.id   count  2017-10                             AngelScript
# 13     actor.id   count  2017-10                              ApacheConf
# 14     actor.id   count  2017-10                                    Apex
# 15     actor.id   count  2017-10                             AppleScript
# 16     actor.id   count  2017-10                                     Arc
# 17     actor.id   count  2017-10                                 Arduino
# 18     actor.id   count  2017-10                                 AspectJ
# 19     actor.id   count  2017-10                                Assembly
# 20     actor.id   count  2017-10                                  Augeas
# 21     actor.id   count  2017-10                              AutoHotkey
# 22     actor.id   count  2017-10                                  AutoIt
# 23     actor.id   count  2017-10                                     Awk
# 24     actor.id   count  2017-10                               Ballerina
# 25     actor.id   count  2017-10                               Batchfile
# 26     actor.id   count  2017-10                                 BitBake
# 27     actor.id   count  2017-10                              BlitzBasic
# 28     actor.id   count  2017-10                                Bluespec
# 29     actor.id   count  2017-10                               Brainfuck
# ...         ...     ...      ...                                     ...
# 58050   repo.id     max  2017-11                                     TXL
# 58051   repo.id     max  2017-11                                     Tcl
# 58052   repo.id     max  2017-11                                     TeX
# 58053   repo.id     max  2017-11                                   Terra
# 58054   repo.id     max  2017-11                                  Thrift
# 58055   repo.id     max  2017-11                              TypeScript
# 58056   repo.id     max  2017-11                            UnrealScript
# 58057   repo.id     max  2017-11                                     VCL
# 58058   repo.id     max  2017-11                                    VHDL
# 58059   repo.id     max  2017-11                                    Vala
# 58060   repo.id     max  2017-11                                 Verilog
# 58061   repo.id     max  2017-11                              Vim script
# 58062   repo.id     max  2017-11                                    VimL
# 58063   repo.id     max  2017-11                            Visual Basic
# 58064   repo.id     max  2017-11                                    Volt
# 58065   repo.id     max  2017-11                                     Vue
# 58066   repo.id     max  2017-11                   Web Ontology Language
# 58067   repo.id     max  2017-11                             WebAssembly
# 58068   repo.id     max  2017-11                                      XC
# 58069   repo.id     max  2017-11                                     XML
# 58070   repo.id     max  2017-11                                   XProc
# 58071   repo.id     max  2017-11                                  XQuery
# 58072   repo.id     max  2017-11                                      XS
# 58073   repo.id     max  2017-11                                    XSLT
# 58074   repo.id     max  2017-11                                   Xtend
# 58075   repo.id     max  2017-11                                    Yacc
# 58076   repo.id     max  2017-11                                    nesC
# 58077   repo.id     max  2017-11                                     ooc
# 58078   repo.id     max  2017-11                                     wdl
# 58079   repo.id     max  2017-11                                   xBase
#
#                  0
# 0              3.0
# 1              3.0
# 2              2.0
# 3              NaN
# 4              1.0
# 5              NaN
# 6              NaN
# 7              7.0
# 8              1.0
# 9              2.0
# 10             NaN
# 11             NaN
# 12             NaN
# 13             8.0
# 14             7.0
# 15             1.0
# 16             NaN
# 17            52.0
# 18             NaN
# 19            23.0
# 20             NaN
# 21             3.0
# 22             NaN
# 23             NaN
# 24             NaN
# 25             9.0
# 26             2.0
# 27             NaN
# 28             NaN
# 29            10.0
# ...            ...
# 58050  108964876.0
# 58051  109869912.0
# 58052  110743954.0
# 58053   50964104.0
# 58054   79456579.0
# 58055  110898549.0
# 58056  110606649.0
# 58057  110655667.0
# 58058  110353453.0
# 58059  110861222.0
# 58060  110889654.0
# 58061  110680864.0
# 58062   77254394.0
# 58063  110856502.0
# 58064   48581027.0
# 58065  110806067.0
# 58066   74678981.0
# 58067  110373312.0
# 58068   47563994.0
# 58069   30999438.0
# 58070   23045033.0
# 58071  110499501.0
# 58072  108800285.0
# 58073  110730797.0
# 58074  110669641.0
# 58075  110439706.0
# 58076  104364498.0
# 58077          NaN
# 58078  105283002.0
# 58079  109899055.0
#
# [58080 rows x 5 columns]

# %%
DATA_FOLDER = '../data'

# %%
df['actor.id'].describe()
# Out:
# count    5.101180e+05
# mean     1.092553e+07
# std      1.063244e+07
# min      7.000000e+00
# 25%      1.325611e+06
# 50%      7.086717e+06
# 75%      1.925088e+07
# max      3.370519e+07
# Name: actor.id, dtype: float64

# %%
import os
os.listdir(DATA_FOLDER)
# Out:
# ['data_2017-10-1_2017-10-1.csv',
#  'data_2017-10-2_2017-10-2.csv',
#  'data_2017-11-10_2017-11-10.csv',
#  'data_2017-11-11_2017-11-11.csv',
#  'data_2017-11-12_2017-11-12.csv',
#  'data_2017-11-13_2017-11-13.csv',
#  'data_2017-11-14_2017-11-14.csv',
#  'data_2017-11-15_2017-11-15.csv',
#  'data_2017-11-1_2017-11-1.csv',
#  'data_2017-11-2_2017-11-2.csv',
#  'data_2017-11-3_2017-11-3.csv',
#  'data_2017-11-4_2017-11-4.csv',
#  'data_2017-11-5_2017-11-5.csv',
#  'data_2017-11-6_2017-11-6.csv',
#  'data_2017-11-7_2017-11-7.csv',
#  'data_2017-11-8_2017-11-8.csv',
#  'data_2017-11-9_2017-11-9.csv']

# %%
all_dates = list(map(lambda x: x.strftime('%Y-%m-%d').replace('-0', '-'), 
         list(pd.date_range('2017-11-1', '2017-11-15'))))

# %%
all_files_requeried = list(map(lambda x: 'data_{d}_{d}.csv'.format(d=x), all_dates))

# %%
all_files_requeried
# Out:
# ['data_2017-11-1_2017-11-1.csv',
#  'data_2017-11-2_2017-11-2.csv',
#  'data_2017-11-3_2017-11-3.csv',
#  'data_2017-11-4_2017-11-4.csv',
#  'data_2017-11-5_2017-11-5.csv',
#  'data_2017-11-6_2017-11-6.csv',
#  'data_2017-11-7_2017-11-7.csv',
#  'data_2017-11-8_2017-11-8.csv',
#  'data_2017-11-9_2017-11-9.csv',
#  'data_2017-11-10_2017-11-10.csv',
#  'data_2017-11-11_2017-11-11.csv',
#  'data_2017-11-12_2017-11-12.csv',
#  'data_2017-11-13_2017-11-13.csv',
#  'data_2017-11-14_2017-11-14.csv',
#  'data_2017-11-15_2017-11-15.csv']

# %%
datetime.now().strftime('%Y-%m-%d')
# Out:
# '2017-11-20'

# %%
if set(all_files_requeried) - set(os.listdir(DATA_FOLDER)):
    print('nok')
else:
    print('ok')
# Out:
# ok

# %%
d = pd.DataFrame(df.groupby(['payload.pull_request.base.repo.language', 'cohort']).size()).reset_index()

# %%
_71.merge(d, on=LANGUE_COL, how='left').shape
# Out:
# (58080, 6)

# %%
_71.shape
# Out:
# (58080, 5)

# %%
lan = df['payload.pull_request.base.repo.language'].unique()

# %%
lan
# Out:
# array(['Ruby', 'Python', 'C#', 'JavaScript', 'Go', 'Java', 'Swift',
#        'Smarty', 'C', 'PHP', 'HTML', 'CSS', 'TypeScript', 'Common Lisp',
#        'SQLPL', 'C++', 'Batchfile', 'Perl 6', 'Pascal', 'SaltStack',
#        'Dart', 'OCaml', 'Jupyter Notebook', 'TeX', 'Kotlin', 'Vue', 'Lua',
#        'ActionScript', 'Scala', 'Perl', 'R', 'HCL', 'Groovy', 'Shell',
#        'Verilog', 'Makefile', 'Nix', 'Agda', 'Gherkin', 'Assembly',
#        'Emacs Lisp', 'PowerShell', 'Clojure', 'Tcl', 'Objective-C',
#        'CoffeeScript', 'Rust', 'P4', 'Processing', 'Haskell', 'Elixir',
#        'Lasso', 'XSLT', 'Erlang', 'SourcePawn', 'FreeMarker', 'Matlab',
#        'Julia', 'DM', 'Yacc', 'PureScript', 'Forth', 'CMake', 'Fortran',
#        'MAXScript', 'Coq', 'Haxe', 'Vim script', 'Arduino', 'VimL',
#        'GDScript', 'PLpgSQL', 'Elm', 'Eiffel', 'BitBake', 'Roff', 'Vala',
#        'D', 'SystemVerilog', 'LilyPond', 'Eagle', 'Standard ML',
#        'Modelica', 'M', 'ANTLR', 'COBOL', 'Crystal', 'F#', 'ASP',
#        'ShaderLab', 'Liquid', 'PicoLisp', 'QML', 'GLSL', 'Awk', 'Xtend',
#        'Puppet', 'Visual Basic', 'Logos', 'RAML', 'Nim', 'Cuda', 'QMake',
#        'RobotFramework', 'OpenSCAD', 'VHDL', 'WebAssembly', 'ColdFusion',
#        'CLIPS', 'EmberScript', 'SQF', '1C Enterprise', 'xBase', 'PLSQL',
#        'NSIS', 'AutoHotkey', 'Chapel', 'ApacheConf', 'GAP', 'NewLisp',
#        'wdl', 'Inform 7', 'M4', 'SMT', 'Nginx', 'Gosu', 'Racket',
#        'Objective-C++', 'Protocol Buffer', 'Pony', 'Apex', 'UnrealScript',
#        'DIGITAL Command Language', 'Rascal', 'Ada', 'Scheme', 'Brainfuck',
#        'Brightscript', 'Smalltalk', 'Max', 'XQuery', 'AMPL', 'Mathematica',
#        'LabVIEW', 'PostScript', 'API Blueprint', 'LookML', 'Lex', 'Ring',
#        'SAS', 'DTrace', 'Mako', 'RenderScript', 'Inno Setup', 'KiCad',
#        'Scilab', 'NCL', 'Isabelle', 'Prolog', 'AngelScript', 'Perl6',
#        'CartoCSS', 'OpenEdge ABL', 'Gnuplot', 'Web Ontology Language',
#        'Csound Document', 'Nimrod', 'POV-Ray SDL', 'Thrift',
#        'GCC Machine Description', 'VCL', 'Factor', "Ren'Py", 'REALbasic',
#        'Hack', 'APL', 'FORTRAN', 'Ballerina', 'Alloy', 'LSL', 'XS', 'HLSL',
#        'REXX', 'XC', 'nesC', 'Stan', 'AspectJ', 'LLVM', 'Augeas',
#        'LiveScript', 'Pan', 'Lean', 'SuperCollider', 'Limbo', 'PureBasic',
#        'XML', 'Idris', 'Smali', 'NetLogo', 'Squirrel', 'Ceylon', 'ABAP',
#        'IDL', 'MoonScript', 'Harbour', 'SRecode Template', 'Objective-J',
#        'Ragel', 'Metal', 'E', 'Stata', 'Game Maker Language', 'Terra',
#        'TLA', 'Pure Data', 'PAWN', 'AutoIt', 'HyPhy', 'CWeb', 'Cucumber',
#        'AppleScript', 'Component Pascal', 'Volt', 'Bluespec', 'BlitzBasic',
#        'Parrot', 'Mercury', 'XProc', 'Clean', 'FLUX', 'Arc', 'Oz',
#        'Papyrus', 'EQ', 'Io', 'TXL', 'Bro', 'MQL4', 'Red', 'ooc',
#        'AGS Script', 'Self'], dtype=object)

# %%
set(df[df['payload.pull_request.base.repo.language']=='Ruby']['actor.id'].unique())
# Out:
# {17399809,
#  7,
#  3899400,
#  31817736,
#  1441807,
#  3112976,
#  163884,
#  65587,
#  10747958,
#  28868663,
#  18612278,
#  983101,
#  884801,
#  1704002,
#  65608,
#  10846283,
#  78,
#  2785359,
#  360528,
#  393295,
#  1146964,
#  85,
#  18219096,
#  88,
#  17170524,
#  95,
#  21069923,
#  25854052,
#  26738789,
#  1998949,
#  32876,
#  108,
#  32014449,
#  115,
#  32885,
#  557177,
#  6979707,
#  24215676,
#  9994372,
#  32407693,
#  32920,
#  22216856,
#  2457753,
#  154,
#  15696030,
#  5734559,
#  33554592,
#  3113120,
#  1507490,
#  163,
#  1900704,
#  196777,
#  16613548,
#  25264303,
#  622771,
#  30507193,
#  33620154,
#  426179,
#  199,
#  983242,
#  24543436,
#  22479053,
#  31228110,
#  65746,
#  211,
#  215,
#  98526,
#  98528,
#  13435109,
#  233,
#  235,
#  6586606,
#  884975,
#  3866868,
#  426230,
#  5603579,
#  251,
#  6226175,
#  6193413,
#  263,
#  196872,
#  131337,
#  655627,
#  30605582,
#  1278223,
#  32014609,
#  277,
#  30212388,
#  292,
#  5243178,
#  33620268,
#  9208110,
#  1540402,
#  32702772,
#  26444088,
#  2261308,
#  12615997,
#  33620289,
#  33090,
#  2195781,
#  29655367,
#  12091719,
#  11305290,
#  29065548,
#  33111,
#  2163040,
#  1737058,
#  131427,
#  360803,
#  357,
#  557414,
#  10748272,
#  18022770,
#  22315378,
#  491891,
#  557430,
#  16286071,
#  379,
#  11731325,
#  5636481,
#  1540483,
#  3277190,
#  1212806,
#  5964166,
#  404,
#  22380950,
#  1868186,
#  2359706,
#  9699741,
#  32047518,
#  295329,
#  29622693,
#  197031,
#  5996967,
#  1180082,
#  1540531,
#  393653,
#  33211,
#  17039805,
#  5112255,
#  31097283,
#  13894089,
#  461,
#  9372109,
#  33231,
#  688589,
#  14942680,
#  12157406,
#  6750687,
#  885223,
#  491,
#  11698668,
#  590317,
#  500,
#  2064886,
#  1573369,
#  28475900,
#  33423870,
#  11698687,
#  2458112,
#  7504391,
#  9142800,
#  295446,
#  4358683,
#  8815145,
#  559,
#  164400,
#  131641,
#  33456700,
#  13369917,
#  66112,
#  577,
#  20972099,
#  23528010,
#  26346061,
#  9208400,
#  131668,
#  599,
#  11141722,
#  1147484,
#  608,
#  19268194,
#  610,
#  5931623,
#  492138,
#  12452459,
#  25068140,
#  1671796,
#  8979062,
#  630,
#  98936,
#  20087430,
#  13107847,
#  1671822,
#  4260509,
#  1606304,
#  11928226,
#  31883939,
#  131752,
#  1180335,
#  690,
#  23528133,
#  459462,
#  7078603,
#  30474956,
#  5112525,
#  21988050,
#  724,
#  730,
#  21693151,
#  7275238,
#  10552042,
#  131818,
#  32375554,
#  7865096,
#  20906768,
#  16679701,
#  787225,
#  797,
#  29786912,
#  32703264,
#  15139618,
#  15074090,
#  983853,
#  30671663,
#  24740660,
#  31294261,
#  27493179,
#  7635776,
#  1803073,
#  1246020,
#  525124,
#  29393749,
#  983897,
#  164703,
#  394081,
#  31163236,
#  3441519,
#  1278836,
#  1868662,
#  30638967,
#  33358713,
#  5833603,
#  901,
#  131982,
#  9700239,
#  197522,
#  33489814,
#  2360224,
#  17105833,
#  10421173,
#  33555383,
#  656318,
#  230335,
#  20317131,
#  24544203,
#  12157902,
#  975,
#  1901520,
#  918484,
#  3834839,
#  984,
#  820186,
#  6161374,
#  24773607,
#  33770,
#  1027,
#  15860743,
#  1034,
#  66577,
#  3638289,
#  32801814,
#  25494552,
#  754712,
#  1051,
#  1060,
#  28050468,
#  1062,
#  1066,
#  10683436,
#  16483373,
#  1090,
#  1213510,
#  10257491,
#  5014611,
#  25396319,
#  12911712,
#  3769441,
#  31425638,
#  14222439,
#  17040491,
#  33914,
#  22840445,
#  7963776,
#  17728655,
#  951452,
#  32441502,
#  33096871,
#  1901741,
#  197810,
#  11306163,
#  1206,
#  26150070,
#  1211,
#  3474627,
#  722117,
#  16549068,
#  853210,
#  361691,
#  7832803,
#  2295014,
#  16647400,
#  525548,
#  2262255,
#  23135475,
#  27657462,
#  4097271,
#  230654,
#  9110785,
#  32310532,
#  1286,
#  16418059,
#  66836,
#  8094998,
#  30246173,
#  30246179,
#  29066532,
#  28542247,
#  32408872,
#  14058792,
#  329012,
#  28214583,
#  17466680,
#  22054206,
#  7963978,
#  14288202,
#  30246224,
#  165205,
#  18122077,
#  10552669,
#  8455520,
#  12518762,
#  10487152,
#  19268982,
#  11699595,
#  1410448,
#  22742423,
#  12780953,
#  1312165,
#  32310699,
#  21988780,
#  853423,
#  22382000,
#  99763,
#  1465,
#  22119877,
#  13534680,
#  7734747,
#  29001188,
#  27756008,
#  12256750,
#  29820406,
#  9012727,
#  20055547,
#  6850045,
#  1148415,
#  25593345,
#  2459151,
#  7702035,
#  67093,
#  32441877,
#  12617241,
#  33031706,
#  1410587,
#  787998,
#  1574,
#  9537073,
#  67123,
#  1589,
#  28739135,
#  1599,
#  32376390,
#  31327832,
#  5670489,
#  3311200,
#  1443426,
#  1869412,
#  9569897,
#  1642,
#  5998190,
#  4195952,
#  1654,
#  67192,
#  13371001,
#  25921151,
#  7046787,
#  67209,
#  951947,
#  23365268,
#  9438868,
#  5899929,
#  9275050,
#  16549562,
#  8423099,
#  100029,
#  4327102,
#  1410750,
#  296649,
#  493257,
#  8128204,
#  1640143,
#  8062679,
#  25888473,
#  32409319,
#  19597045,
#  1541878,
#  26806017,
#  2426636,
#  3540752,
#  7440154,
#  1214238,
#  591655,
#  6457128,
#  100142,
#  329521,
#  67381,
#  26085175,
#  26216252,
#  28280639,
#  395077,
#  4982601,
#  4622154,
#  25331532,
#  5343054,
#  14092115,
#  1880,
#  984938,
#  6358893,
#  1903,
#  2918256,
#  7309170,
#  14059382,
#  591737,
#  1915,
#  395132,
#  3475327,
#  1930,
#  690069,
#  1476506,
#  23168925,
#  591781,
#  1181607,
#  2033576,
#  30836651,
#  1968046,
#  15337391,
#  18122672,
#  5015473,
#  16811954,
#  2328503,
#  34746,
#  1902527,
#  1994,
#  1017808,
#  2010,
#  24217563,
#  2721757,
#  165857,
#  14190564,
#  24283119,
#  5474309,
#  2951180,
#  1312783,
#  591889,
#  25004055,
#  2073,
#  6785060,
#  12912687,
#  2095,
#  5769281,
#  329800,
#  1378379,
#  2129,
#  2130,
#  6359128,
#  2142,
#  624736,
#  31230052,
#  6424683,
#  6031480,
#  2177,
#  788611,
#  4229252,
#  1935501,
#  133262,
#  723088,
#  1443986,
#  10848407,
#  1247390,
#  24643743,
#  2208,
#  2214,
#  24578215,
#  428200,
#  1902763,
#  2221,
#  2001078,
#  15960249,
#  28739771,
#  4327616,
#  1149122,
#  526530,
#  33556677,
#  20678855,
#  133328,
#  264400,
#  15632598,
#  67804,
#  12290272,
#  19761376,
#  1050851,
#  1804518,
#  2132216,
#  25594109,
#  7407875,
#  231684,
#  264455,
#  362783,
#  11405600,
#  3475744,
#  2340,
#  4786472,
#  2132267,
#  5278006,
#  1018168,
#  16714045,
#  6949191,
#  985416,
#  2381,
#  32409935,
#  1476952,
#  29428058,
#  15796572,
#  133476,
#  395621,
#  624999,
#  100718,
#  32082291,
#  35192,
#  27232646,
#  428423,
#  4721034,
#  16124299,
#  2984336,
#  7408017,
#  4098453,
#  15108502,
#  7047579,
#  8161693,
#  11995551,
#  33491362,
#  166314,
#  30607790,
#  1673649,
#  100796,
#  25627074,
#  11340230,
#  3049938,
#  11635158,
#  17533399,
#  11635177,
#  20777451,
#  16878059,
#  3672559,
#  29264372,
#  166389,
#  1837560,
#  31230468,
#  2567,
#  559627,
#  3246607,
#  27298326,
#  4262445,
#  1804856,
#  3082811,
#  13077061,
#  25856583,
#  9308749,
#  2394703,
#  2655,
#  166511,
#  2671,
#  17271411,
#  5638782,
#  2687,
#  9996926,
#  30608004,
#  887429,
#  2230917,
#  6654600,
#  25561744,
#  2715,
#  527009,
#  1313442,
#  28478121,
#  7080621,
#  1018543,
#  7572153,
#  26905274,
#  25627334,
#  199368,
#  7015115,
#  17664716,
#  31492813,
#  953037,
#  13863631,
#  25037515,
#  2780,
#  527069,
#  2784,
#  4164335,
#  12749558,
#  24775423,
#  2819,
#  31230735,
#  2843,
#  21105450,
#  22481727,
#  1706826,
#  5770060,
#  6490959,
#  2591569,
#  5933907,
#  232278,
#  31525719,
#  1051484,
#  2909,
#  2911,
#  2912,
#  12716898,
#  7932772,
#  32148331,
#  23530352,
#  33524593,
#  28642163,
#  2944,
#  15698823,
#  1706896,
#  6065041,
#  17009559,
#  16944030,
#  9145247,
#  330659,
#  134055,
#  26610599,
#  30411692,
#  4361134,
#  3836852,
#  33196991,
#  166847,
#  24415168,
#  6425542,
#  3014,
#  199624,
#  15338441,
#  33590218,
#  30477263,
#  3025,
#  2952145,
#  33622997,
#  28707806,
#  31132651,
#  9210860,
#  31722491,
#  3378171,
#  10980350,
#  756736,
#  2362370,
#  6130700,
#  3738638,
#  3090,
#  28871711,
#  2493473,
#  30182438,
#  1707056,
#  1313844,
#  9178166,
#  9440312,
#  3134,
#  5442626,
#  14650436,
#  199755,
#  33197138,
#  29428824,
#  35932,
#  3166,
#  3169,
#  10751085,
#  68717,
#  10554478,
#  11963507,
#  35955,
#  298107,
#  35966,
#  199807,
#  18058374,
#  33131661,
#  33557646,
#  8424592,
#  11603089,
#  625811,
#  6524052,
#  17140887,
#  2002078,
#  691365,
#  1641638,
#  3241,
#  887984,
#  30706873,
#  1313981,
#  8162496,
#  3476681,
#  2788556,
#  2755788,
#  134351,
#  22088912,
#  1150162,
#  15371481,
#  167131,
#  953563,
#  36066,
#  1707248,
#  36084,
#  2034936,
#  12487929,
#  12127480,
#  31427850,
#  36106,
#  855306,
#  3341,
#  363800,
#  199961,
#  36124,
#  24513830,
#  21040440,
#  15076665,
#  1346876,
#  26643781,
#  17730886,
#  32574809,
#  134495,
#  29101410,
#  134501,
#  3432,
#  30379369,
#  3438,
#  2231664,
#  2067825,
#  429433,
#  25595266,
#  462213,
#  22089104,
#  10685841,
#  527760,
#  2067859,
#  15371677,
#  27856297,
#  3504,
#  3505,
#  1641910,
#  1445303,
#  14192060,
#  4197823,
#  4787647,
#  8031689,
#  3535,
#  3536,
#  134610,
#  2231765,
#  28904930,
#  16616931,
#  3557,
#  24940010,
#  27790828,
#  3565,
#  25136631,
#  26217980,
#  27692541,
#  3586,
#  23367170,
#  5934604,
#  69151,
#  25890337,
#  3620,
#  11341355,
#  4492844,
#  25005622,
#  27692605,
#  11439679,
#  30838353,
#  3668,
#  5082711,
#  527963,
#  233054,
#  1052259,
#  28184166,
#  26218090,
#  134764,
#  31297135,
#  1740401,
#  1248903,
#  22154889,
#  27692684,
#  20680337,
#  4755090,
#  1248917,
#  757401,
#  17960603,
#  9408157,
#  12848803,
#  3673765,
#  1216167,
#  102056,
#  20385449,
#  331436,
#  3018412,
#  2592431,
#  16944816,
#  5639859,
#  17731259,
#  12848835,
#  3788,
#  20909776,
#  23006936,
#  29789922,
#  24874723,
#  12390123,
#  18124524,
#  3829,
#  3832,
#  30379773,
#  1445635,
#  3846,
#  5705481,
#  9932557,
#  3859,
#  790299,
#  9768731,
#  3879,
#  429876,
#  7049020,
#  4624197,
#  27725639,
#  22875979,
#  3921,
#  397138,
#  14913363,
#  1642324,
#  16813908,
#  8130397,
#  11964258,
#  12160875,
#  855918,
#  27955061,
#  233334,
#  1249142,
#  10555255,
#  5640057,
#  30248832,
#  3970,
#  8916877,
#  3981,
#  7573396,
#  3608471,
#  30576539,
#  3999,
#  429985,
#  19763105,
#  26349475,
#  69542,
#  14323629,
#  69561,
#  855995,
#  26152892,
#  2658237,
#  33296323,
#  32935875,
#  167882,
#  6524882,
#  29298651,
#  4755420,
#  4067,
#  7016425,
#  2363371,
#  1544172,
#  3739631,
#  11931636,
#  4085,
#  4086,
#  28577787,
#  17010683,
#  954367,
#  22089727,
#  135171,
#  36869,
#  4104,
#  167946,
#  13078549,
#  3444760,
#  4122,
#  954402,
#  135205,
#  692265,
#  4138,
#  29560879,
#  29724722,
#  167989,
#  11800640,
#  17109060,
#  12881990,
#  32149575,
#  4169,
#  23040076,
#  135246,
#  4182,
#  4183,
#  23040094,
#  1183838,
#  168030,
#  1839202,
#  954468,
#  888940,
#  4205,
#  3018864,
#  16519293,
#  20484222,
#  32411779,
#  69764,
#  15241365,
#  7606442,
#  28119213,
#  14258352,
#  10981552,
#  2887858,
#  1937586,
#  26349747,
#  102580,
#  4283,
#  987328,
#  233676,
#  2429132,
#  25202898,
#  790743,
#  4312,
#  69851,
#  13635808,
#  954596,
#  135402,
#  758001,
#  16847094,
#  1118459,
#  8458492,
#  4351,
#  4352,
#  8556812,
#  24285453,
#  1904911,
#  6590748,
#  4381,
#  4383,
#  2527520,
#  8032543,
#  29036832,
#  1904928,
#  19730728,
#  25727274,
#  37162,
#  69933,
#  30085423,
#  856376,
#  2920760,
#  24416574,
#  19665216,
#  6656328,
#  11440456,
#  430411,
#  13799755,
#  1446224,
#  37206,
#  13701468,
#  29102440,
#  11538793,
#  30609773,
#  26874222,
#  17731951,
#  30609777,
#  20156786,
#  16028024,
#  364924,
#  31560062,
#  ...}

# %%
set(df[df['payload.pull_request.base.repo.language']=='Python']['actor.id'].unique())
.intersection(set(df[df['payload.pull_request.base.repo.language']=='Ruby']['actor.id'].unique()))
# Out:
# {108,
#  461,
#  1090,
#  2214,
#  3859,
#  3921,
#  6321,
#  7241,
#  7907,
#  8100,
#  8706,
#  12266,
#  16928,
#  18304,
#  19618,
#  22728,
#  23066,
#  26463,
#  28623,
#  30216,
#  40044,
#  45400,
#  48100,
#  48997,
#  49494,
#  55744,
#  55913,
#  63651,
#  63736,
#  86922,
#  87579,
#  92604,
#  98528,
#  103932,
#  112292,
#  118063,
#  119659,
#  120890,
#  125011,
#  130393,
#  161495,
#  169448,
#  170966,
#  187987,
#  188402,
#  207759,
#  230335,
#  273454,
#  282446,
#  293363,
#  301220,
#  333335,
#  355079,
#  369941,
#  370205,
#  387407,
#  392266,
#  395132,
#  417859,
#  428423,
#  429433,
#  429985,
#  451510,
#  458717,
#  464871,
#  474649,
#  478564,
#  479088,
#  501702,
#  503804,
#  509703,
#  510498,
#  537221,
#  570901,
#  589034,
#  600897,
#  613538,
#  649496,
#  697848,
#  706257,
#  726704,
#  731232,
#  732321,
#  768067,
#  846795,
#  855306,
#  864213,
#  902384,
#  903479,
#  910753,
#  925372,
#  948901,
#  959640,
#  959761,
#  985416,
#  997613,
#  1018168,
#  1050851,
#  1067203,
#  1130010,
#  1134497,
#  1144873,
#  1278836,
#  1309895,
#  1328448,
#  1329219,
#  1381991,
#  1410448,
#  1445635,
#  1467310,
#  1533818,
#  1560405,
#  1578328,
#  1581140,
#  1636576,
#  1678271,
#  1684030,
#  1690993,
#  1751166,
#  1958514,
#  1965489,
#  1991473,
#  1996632,
#  2151059,
#  2163040,
#  2181522,
#  2243323,
#  2310840,
#  2346907,
#  2480492,
#  2592431,
#  2631566,
#  2721757,
#  2755788,
#  2871527,
#  2920760,
#  2927722,
#  3101557,
#  3189125,
#  3275593,
#  3464626,
#  3579859,
#  3776423,
#  3798513,
#  4006149,
#  4260509,
#  4418817,
#  4599889,
#  4721034,
#  4912500,
#  5364817,
#  5593699,
#  5683582,
#  5693853,
#  6061440,
#  6179191,
#  6273743,
#  6348990,
#  6404125,
#  6532136,
#  6646324,
#  6763301,
#  6805534,
#  6880594,
#  7057548,
#  7194142,
#  7217130,
#  7218875,
#  7228605,
#  7275238,
#  7408017,
#  7606442,
#  7754028,
#  7832803,
#  7839104,
#  8197693,
#  8327751,
#  8505044,
#  8716070,
#  8939619,
#  9055556,
#  10406565,
#  10487152,
#  10714426,
#  10902110,
#  11022652,
#  11054010,
#  11446617,
#  12127480,
#  12452459,
#  12848803,
#  12881990,
#  12971349,
#  13123663,
#  13135483,
#  13712403,
#  13836290,
#  13883875,
#  14000840,
#  14369357,
#  14542386,
#  15019099,
#  15334952,
#  15801696,
#  16249260,
#  16558355,
#  16560457,
#  16791330,
#  16944816,
#  18176485,
#  20948594,
#  21105450,
#  22705973,
#  22815766,
#  24775423,
#  25627074,
#  25825996,
#  25983467,
#  26152892,
#  26218090,
#  26384082,
#  27232646,
#  27856297,
#  28280639,
#  28788585,
#  29153608,
#  29289679,
#  30192484,
#  30379773,
#  31147999,
#  32517028,
#  32935875,
#  33370369,
#  33430740,
#  33478776,
#  33571208,
#  33643692,
#  33647621}

# %%
for l1 in lan:
    for l2 in lan:
        actors_l1 = df[df['payload.pull_request.base.repo.language'] == l1]['actor.display_login'].unique()
        n = df[(df['payload.pull_request.base.repo.language'] == l2) & 
               (df[df['actor.display_login'].apply(lambda x: x in actors_l1)])]
        print(l1, l2, n)
